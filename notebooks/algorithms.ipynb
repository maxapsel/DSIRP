# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    if sorted(word1.lower()) == sorted(word2.lower()):
        return True
    else:
        return False

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 1.69 µs ± 291 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 3.7 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
def all_anagram_pairs(word_list):
    pair_list = []
    for i in range(len(word_list) - 1):
        for j in range(i + 1, len(word_list) - 1):
            if is_anagram(word_list[i], word_list[j]):
                if word_list[i] not in pair_list:
                    pair_list.append(word_list[i])
                if word_list[j] not in pair_list:
                    pair_list.append(word_list[j])
    return pair_list

# %%
all_anagram_pairs(short_word_list)
# Out:
# ['stop', 'pots', 'tops']

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            if "'" not in word:
                res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 72324

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
stop_pairs = []
for word in word_list:
    if is_anagram(word, "stop"):
        stop_pairs.append(word)
print(stop_pairs)
# Out:
# ['pots', 'post', 'opts', 'tops', 'stop', 'spot']

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
#pairs = all_anagram_pairs(list(word_list))
#print(pairs)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %%
#90 minutes

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    anagram_list = []
    dict = {}

    for item in word_list:
        sorted_item = ''.join(sorted(item))
        if sorted_item not in dict:
            dict[sorted_item] = [item]
        else:
            dict[sorted_item].append(item)
        
    return dict

# %%
pairs = all_anagram_lists(word_list)
#print(pairs)
# Out:
# {'eeinntw': ['entwine'], 'acgiknp': ['packing'], 'aaceiilmnstx': ['anticlimaxes'], 'aabcdehkl': ['blackhead'], 'aacgiiilnptz': ['capitalizing'], 'eemnyz': ['enzyme'], 'aeeiiilnssstttx': ['existentialists'], 'definrs': ['friends', 'finders'], 'iklmy': ['milky'], 'adlny': ['lynda', 'dylan'], 'cflllooruy': ['colorfully'], 'bcdeehl': ['belched'], 'acellrs': ['callers', 'cellars', 'recalls'], 'deju': ['jude'], 'acprs': ['craps', 'carps', 'scrap'], 'dginot': ['doting'], 'aaeeilnrttv': ['alternative'], 'ceghint': ['etching'], 'gginootu': ['outgoing'], 'aeemrrs': ['reamers'], 'acehkorst': ['shortcake'], 'adilmopsy': ['olympiads'], 'addeilnnsy': ['disneyland'], 'acchiot': ['chaotic'], 'aceorssu': ['carouses'], 'aeiiilmprsst': ['imperialists'], 'adeilost': ['isolated'], 'adeefglnnw': ['newfangled'], 'aadegiilprz': ['plagiarized'], 'aelooprrtxy': ['exploratory'], 'cegiiknnqu': ['quickening'], 'ipqu': ['quip'], 'aeinprst': ['repaints', 'pertains', 'pantries', 'painters'], 'defilptu': ['uplifted'], 'adeeiiprstv': ['depravities'], 'aceilnor': ['caroline', 'cornelia'], 'eotv': ['vote', 'veto'], 'ceeinosssstuv': ['viscountesses'], 'ceeimnoorsu': ['ceremonious'], 'aeegttz': ['gazette'], 'aeflnortuy': ['fauntleroy'], 'dghiins': ['dishing', 'shindig'], 'eiinpsst': ['spiniest'], 'aeelmst': ['maltese'], 'aiprssu': ['prussia'], 'eirttv': ['trivet'], 'aaciilmnorttu': ['matriculation'], 'aaccinostu': ['accusation'], 'deefht': ['hefted'], 'acdekqu': ['quacked'], 'addeeoprs': ['desperado'], 'aceilmnrttu': ['curtailment'], 'effnrssu': ['snuffers'], 'aevw': ['wave'], 'eflrsttu': ['flutters'], 'eeprt': ['peter'], 'fgillnoosw': ['followings'], 'amnrttu': ['tantrum'], 'aelrv': ['ravel'], 'cilps': ['clips'], 'ceeeimnttx': ['excitement'], 'adeiinnnott': ['indentation'], 'bbdego': ['gobbed'], 'ekooprv': ['provoke'], 'giinnnw': ['winning'], 'dhortu': ['drouth'], 'ehikrrs': ['shirker'], 'rsttuy': ['trusty'], 'gilmmnoos': ['mongolism'], 'acgiinnoooprstt': ['prognostication'], 'accegilloo': ['ecological'], 'aciilrsttu': ['altruistic'], 'jloosuyy': ['joyously'], 'accdeeinnnst': ['incandescent'], 'aceinops': ['canopies'], 'addeefhoorsw': ['foreshadowed'], 'aaprt': ['apart'], 'aadkrww': ['awkward'], 'cenrsuw': ['unscrew'], 'acegly': ['legacy'], 'ampst': ['tamps', 'stamp'], 'agglsu': ['gulags'], 'dilpstuy': ['stupidly'], 'acdiinortv': ['vindicator'], 'aakrst': ['karats'], 'abdeegiilnrt': ['deliberating'], 'egnnotuv': ['vonnegut'], 'aadeelpp': ['appealed'], 'cgghiinr': ['gingrich'], 'ceginorst': ['escorting', 'corseting'], 'dehnoow': ['hoedown'], 'adeeiilsz': ['idealizes'], 'addeehiknrt': ['kindhearted'], 'airrty': ['rarity'], 'aails': ['alisa', 'alias'], 'aahkmmr': ['markham'], 'aclsy': ['scaly'], 'aeegglnoy': ['genealogy'], 'abehirrtt': ['birthrate'], 'adeefr': ['deafer', 'feared'], 'ikmnoo': ['kimono'], 'aaelprssy': ['paralyses'], 'addeeloorv': ['overloaded'], 'cdghinou': ['douching'], 'egopr': ['grope'], 'filmrssttuu': ['mistrustful'], 'deemn': ['emend'], 'eloy': ['eloy'], 'ellu': ['elul'], 'aceeknp': ['kneecap'], 'adhnrty': ['hydrant'], 'ceeoqrttu': ['croquette'], 'eilmpty': ['emptily'], 'cehpsstu': ['putsches'], 'adiv': ['diva', 'avid'], 'eeinrsty': ['serenity'], 'dsstu': ['studs', 'dusts'], 'eiloprsuvy': ['previously'], 'fgiimnnor': ['informing'], 'cdeir': ['riced', 'cider', 'cried'], 'giloorsstu': ['urologists'], 'bdenor': ['borden'], 'agiinnrs': ['ingrains'], 'eiopprstuv': ['supportive'], 'aginprw': ['warping'], 'ainrssu': ['russian'], 'aefkr': ['faker', 'freak'], 'beffru': ['rebuff', 'buffer'], 'ceemoorv': ['overcome'], 'bemssuu': ['subsume'], 'eehnorw': ['erewhon', 'nowhere', 'whereon'], 'aaegiimnnottz': ['magnetization'], 'aeilns': ['alines', 'aliens', 'saline'], 'aaggiiilnprz': ['plagiarizing'], 'aeenst': ['sateen', 'senate'], 'aaddlrsty': ['dastardly'], 'deeorstx': ['dextrose'], 'osstw': ['stows'], 'aaelnprty': ['planetary'], 'dgilu': ['guild'], 'deeimnoprt': ['redemption'], 'acefil': ['facile'], 'aceikmrv': ['maverick'], 'acdenrt': ['tancred'], 'aiopstu' ...

# %%
# %time anagram_map = all_anagram_lists(word_list)
# Out:
# CPU times: user 356 ms, sys: 47 ms, total: 403 ms
# Wall time: 1.24 s

# %%
len(anagram_map)
# Out:
# 66614

# %%
#print(anagram_map)

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
def new_dict(dict):
    multiples_map = {}
    for key,value in dict.items():
        if len(value) >= 2:
            multiples_map[key] = value
    return multiples_map

# %%
map = new_dict(all_anagram_lists(word_list))
#print(map)

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
longest_word = ['']
for key,value in map.items():
    if len(value[0]) > len(longest_word[0]):
        longest_word = value
print(longest_word)
# Out:
# ['tablespoonsful', 'tablespoonfuls']

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
most_anagrams = []
for key,value in map.items():
    if len(value) > len(most_anagrams):
        most_anagrams = value
print(most_anagrams)
# Out:
# ['stale', 'steal', 'tesla', 'stael', 'teals', 'tales', 'slate', 'least']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
def exerciseTen(word_length):
    most_anagrams = []
    for key,value in map.items():
        if len(value) > len(most_anagrams) and len(value[0]) == word_length:
            most_anagrams = value
    return most_anagrams

# %%
print(exerciseTen(6))
# Out:
# ['caters', 'recast', 'crates', 'reacts', 'traces', 'carets', 'caster']

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
import math
def all_pair(map):
    pairs_total = 0
    for key,value in map.items():
        pairs_total += (math.factorial(len(value)) / 2)
    return(pairs_total)

# %%
print(int(all_pair(map)))
print(len(map))
# Out:
# 41026
# 4489

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
